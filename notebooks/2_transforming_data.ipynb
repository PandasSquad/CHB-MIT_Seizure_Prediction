# %% [markdown]
# # ⤵️ Process data for modeling ⤴️

# %%
import os
# move to ../src/data_handler.py
os.chdir("../src")
import data_handler
import pandas as pd

# %% [markdown]
# ```mermaid
# graph LR
#
# p[Select patient] --> raw[
# ```

# %%
patients = data_handler.get_patients()

windows = [data_handler.make_patient_windows(patients[0])]
windows[0]
# Out:
# (array([[[-16.21489621,  -8.79120879, -10.74481074, ...,  10.74481074,
#            -5.27472527, -10.74481074],
#          [-12.6984127 ,  -6.83760684,  -9.57264957, ...,   7.22832723,
#            -6.05616606,  -8.79120879],
#          [ -9.18192918,  -2.93040293,  -8.00976801, ...,   2.14896215,
#            -6.05616606,  -6.05616606],
#          ...,
#          [ 42.78388278,  25.59218559, -32.62515263, ...,   3.32112332,
#           -49.42612943, -36.92307692],
#          [ 38.87667888,  25.98290598, -35.36019536, ...,   3.32112332,
#           -49.81684982, -40.04884005],
#          [ 36.53235653,  24.42002442, -36.53235653, ...,   2.53968254,
#           -46.69108669, -41.22100122]],
#
#         [[ 37.7045177 ,  15.82417582, -38.87667888, ...,  15.04273504,
#           -44.73748474, -43.95604396],
#          [ 35.75091575,  10.35409035, -40.83028083, ...,  19.73137973,
#           -34.96947497, -43.56532357],
# ...

# %%
windows[0][0].shape
# Out:
# (420, 1280, 22)

# %%
windows[0][1].shape
# Out:
# (420, 1280, 22)
